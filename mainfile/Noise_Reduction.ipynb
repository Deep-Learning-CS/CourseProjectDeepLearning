# %%
# !pip install speechbrain torchaudio torch
# Out:
# Requirement already satisfied: speechbrain in c:\users\acer\appdata\roaming\python\python311\site-packages (1.0.1)
# Requirement already satisfied: torchaudio in c:\users\acer\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: torch in c:\users\acer\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: hyperpyyaml in c:\users\acer\anaconda3\lib\site-packages (from speechbrain) (1.2.2)
# Requirement already satisfied: joblib in c:\users\acer\anaconda3\lib\site-packages (from speechbrain) (1.2.0)
# Requirement already satisfied: numpy in c:\users\acer\anaconda3\lib\site-packages (from speechbrain) (1.24.3)
# Requirement already satisfied: packaging in c:\users\acer\anaconda3\lib\site-packages (from speechbrain) (23.1)
# Requirement already satisfied: scipy in c:\users\acer\anaconda3\lib\site-packages (from speechbrain) (1.11.1)
# Requirement already satisfied: sentencepiece in c:\users\acer\anaconda3\lib\site-packages (from speechbrain) (0.2.0)
# Requirement already satisfied: tqdm in c:\users\acer\anaconda3\lib\site-packages (from speechbrain) (4.65.0)
# Requirement already satisfied: huggingface-hub in c:\users\acer\anaconda3\lib\site-packages (from speechbrain) (0.15.1)
# Requirement already satisfied: filelock in c:\users\acer\anaconda3\lib\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\acer\anaconda3\lib\site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in c:\users\acer\anaconda3\lib\site-packages (from torch) (1.11.1)
# Requirement already satisfied: networkx in c:\users\acer\anaconda3\lib\site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in c:\users\acer\anaconda3\lib\site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\acer\anaconda3\lib\site-packages (from torch) (2023.4.0)
# Requirement already satisfied: requests in c:\users\acer\anaconda3\lib\site-packages (from huggingface-hub->speechbrain) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\acer\anaconda3\lib\site-packages (from huggingface-hub->speechbrain) (6.0)
# Requirement already satisfied: colorama in c:\users\acer\anaconda3\lib\site-packages (from tqdm->speechbrain) (0.4.6)
# Requirement already satisfied: ruamel.yaml>=0.17.28 in c:\users\acer\anaconda3\lib\site-packages (from hyperpyyaml->speechbrain) (0.18.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\acer\anaconda3\lib\site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\acer\anaconda3\lib\site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in c:\users\acer\anaconda3\lib\site-packages (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain) (0.2.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\acer\anaconda3\lib\site-packages (from requests->huggingface-hub->speechbrain) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\anaconda3\lib\site-packages (from requests->huggingface-hub->speechbrain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acer\anaconda3\lib\site-packages (from requests->huggingface-hub->speechbrain) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\anaconda3\lib\site-packages (from requests->huggingface-hub->speechbrain) (2023.7.22)

# %%
import speechbrain
print(speechbrain.__version__)
# Out:
# 1.0.1

# %%
# !pip install speechbrain # if you don't get the above cell, then only run this

# %% [markdown]
# #### the librosa is not using any deep learning technology, but it's there to just make comparison to what the non pretrained model will produce the result like

# %%
# Install necessary libraries
# !pip install noisereduce torchaudio librosa

# Import required libraries
import os  # For checking if the file exists
import torch  # Importing PyTorch
import torchaudio
import noisereduce as nr

# Define the audio file path
audio_file = "example.wav"  # Replace with your actual audio file path

# Check if the audio file exists
if not os.path.isfile(audio_file):
    raise FileNotFoundError(f"The file '{audio_file}' does not exist. Please check the path.")

# Load the audio file
signal, sr = torchaudio.load(audio_file)

# Convert to 1D array (if needed)
if signal.shape[0] > 1:
    signal = signal.mean(dim=0)  # Convert to mono by averaging channels

# Apply noise reduction
denoised_signal = nr.reduce_noise(y=signal.numpy(), sr=sr)

# Convert denoised signal back to a tensor
denoised_tensor = torch.tensor(denoised_signal)

# Ensure the tensor is 2D before saving
if denoised_tensor.ndim == 1:
    denoised_tensor = denoised_tensor.unsqueeze(0)  # Ensure it's a 2D tensor (1, samples)
elif denoised_tensor.ndim > 2:
    raise ValueError(f"Unexpected tensor dimensions: {denoised_tensor.ndim}. Expected 1D or 2D tensor.")

# Save the denoised audio
torchaudio.save("denoised_example.wav", denoised_tensor, sr)

print("Denoising completed. The denoised audio is saved as 'denoised_example.wav'.")
# Out:
# Requirement already satisfied: noisereduce in c:\users\acer\anaconda3\lib\site-packages (3.0.2)
# Requirement already satisfied: torchaudio in c:\users\acer\anaconda3\lib\site-packages (2.4.1)
# Requirement already satisfied: librosa in c:\users\acer\anaconda3\lib\site-packages (0.10.2.post1)
# Requirement already satisfied: scipy in c:\users\acer\anaconda3\lib\site-packages (from noisereduce) (1.11.1)
# Requirement already satisfied: matplotlib in c:\users\acer\anaconda3\lib\site-packages (from noisereduce) (3.7.2)
# Requirement already satisfied: numpy in c:\users\acer\anaconda3\lib\site-packages (from noisereduce) (1.24.3)
# Requirement already satisfied: tqdm in c:\users\acer\anaconda3\lib\site-packages (from noisereduce) (4.65.0)
# Requirement already satisfied: torch==2.4.1 in c:\users\acer\anaconda3\lib\site-packages (from torchaudio) (2.4.1)
# Requirement already satisfied: filelock in c:\users\acer\anaconda3\lib\site-packages (from torch==2.4.1->torchaudio) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\acer\anaconda3\lib\site-packages (from torch==2.4.1->torchaudio) (4.12.2)
# Requirement already satisfied: sympy in c:\users\acer\anaconda3\lib\site-packages (from torch==2.4.1->torchaudio) (1.11.1)
# Requirement already satisfied: networkx in c:\users\acer\anaconda3\lib\site-packages (from torch==2.4.1->torchaudio) (3.1)
# Requirement already satisfied: jinja2 in c:\users\acer\anaconda3\lib\site-packages (from torch==2.4.1->torchaudio) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\acer\anaconda3\lib\site-packages (from torch==2.4.1->torchaudio) (2023.4.0)
# Requirement already satisfied: audioread>=2.1.9 in c:\users\acer\anaconda3\lib\site-packages (from librosa) (3.0.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\acer\anaconda3\lib\site-packages (from librosa) (1.3.0)
# Requirement already satisfied: joblib>=0.14 in c:\users\acer\anaconda3\lib\site-packages (from librosa) (1.2.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\acer\anaconda3\lib\site-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in c:\users\acer\anaconda3\lib\site-packages (from librosa) (0.57.1)
# Requirement already satisfied: soundfile>=0.12.1 in c:\users\acer\anaconda3\lib\site-packages (from librosa) (0.12.1)
# Requirement already satisfied: pooch>=1.1 in c:\users\acer\anaconda3\lib\site-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in c:\users\acer\anaconda3\lib\site-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: lazy-loader>=0.1 in c:\users\acer\anaconda3\lib\site-packages (from librosa) (0.2)
# Requirement already satisfied: msgpack>=1.0 in c:\users\acer\anaconda3\lib\site-packages (from librosa) (1.0.3)
# Requirement already satisfied: llvmlite<0.41,>=0.40.0dev0 in c:\users\acer\anaconda3\lib\site-packages (from numba>=0.51.0->librosa) (0.40.0)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\acer\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (3.10.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (23.1)
# Requirement already satisfied: requests>=2.19.0 in c:\users\acer\anaconda3\lib\site-packages (from pooch>=1.1->librosa) (2.31.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\acer\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->librosa) (2.2.0)
# Requirement already satisfied: cffi>=1.0 in c:\users\acer\anaconda3\lib\site-packages (from soundfile>=0.12.1->librosa) (1.15.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->noisereduce) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->noisereduce) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->noisereduce) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->noisereduce) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->noisereduce) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->noisereduce) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acer\anaconda3\lib\site-packages (from matplotlib->noisereduce) (2.8.2)
# Requirement already satisfied: colorama in c:\users\acer\anaconda3\lib\site-packages (from tqdm->noisereduce) (0.4.6)
# Requirement already satisfied: pycparser in c:\users\acer\anaconda3\lib\site-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.21)
# Requirement already satisfied: six>=1.5 in c:\users\acer\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->noisereduce) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\acer\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\acer\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\acer\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\acer\anaconda3\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\acer\anaconda3\lib\site-packages (from jinja2->torch==2.4.1->torchaudio) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\acer\anaconda3\lib\site-packages (from sympy->torch==2.4.1->torchaudio) (1.3.0)
# Denoising completed. The denoised audio is saved as 'denoised_example.wav'.

# %% [markdown]
# #### Below is the pretrained model from speechbrain and you'll see that there is a contrasting difference between the audio cleared from a pretrained model and one from librosa

# %%
import torchaudio
import torch
import soundfile as sf
import numpy as np
from speechbrain.inference import SepformerSeparation as separator
from IPython.display import Audio

# %%
# Load the pre-trained deep learning model for denoising
model = separator.from_hparams(source="speechbrain/sepformer-wham16k-enhancement", savedir="pretrained_models/sepformer")
# Out:
# C:\Users\acer\AppData\Roaming\Python\Python311\site-packages\speechbrain\utils\checkpoints.py:194: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(path, map_location=device)

# %%
# Load your noisy audio file
audio_file = "example.wav"  # Replace with the path to your audio file
signal, sr = torchaudio.load(audio_file)

# %% [markdown]
# ##### Overclock your GPU(Just a suggestion, you can run the file faster)

# %%
# Apply the denoising model (deep learning)
denoised_signal = model.separate_file(audio_file)

# Ensure the tensor is 2D (channel x samples) by selecting only one channel if necessary
if len(denoised_signal.shape) == 4:
    denoised_signal = denoised_signal.squeeze(0)  # Remove batch dimension

if len(denoised_signal.shape) == 3:
    denoised_signal = denoised_signal[0]  # Select the first source

# Ensure the tensor is 2D (channels x samples)
if len(denoised_signal.shape) != 2:
    raise ValueError("The denoised_signal tensor should be 2D (channels x samples)")

# Convert tensor to numpy array (required by soundfile)
denoised_signal = denoised_signal.numpy()

# Check data type and convert to float32 if necessary
if denoised_signal.dtype != 'float32':
    denoised_signal = denoised_signal.astype('float32')

# Check for NaNs or infinite values
if np.any(np.isnan(denoised_signal)) or np.any(np.isinf(denoised_signal)):
    raise ValueError("The denoised signal contains NaN or infinite values.")

# %%
# Play the denoised audio in the notebook
audio_player = Audio(denoised_signal.T, rate=sr)  # Transpose for channels x samples

# Return the audio player to display it in the output
audio_player
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
